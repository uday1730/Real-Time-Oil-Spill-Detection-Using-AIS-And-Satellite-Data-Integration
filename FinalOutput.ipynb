# %%
import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')

# Load AIS data (example CSV with vessel details and positions)
ais_data = pd.read_csv('AIS_2024_01_29.csv')

# Convert BaseDateTime to datetime format for time-based sorting
ais_data['BaseDateTime'] = pd.to_datetime(ais_data['BaseDateTime'])

# Sort by MMSI and BaseDateTime to analyze each vessel's movement sequentially
ais_data = ais_data.sort_values(['MMSI', 'BaseDateTime'])

# Detect anomalies in AIS data based on speed and course changes
def detect_anomalies(df):
    anomalies = []
    unique_vessels = df['MMSI'].unique()

    for vessel in unique_vessels:
        vessel_data = df[df['MMSI'] == vessel]

        for i in range(1, len(vessel_data)):
            speed_change = abs(vessel_data['SOG'].iloc[i] - vessel_data['SOG'].iloc[i - 1])
            course_change = abs(vessel_data['COG'].iloc[i] - vessel_data['COG'].iloc[i - 1])

            if speed_change > 10 or course_change > 30:
                anomalies.append(vessel_data.iloc[i])

    return pd.DataFrame(anomalies)

# Detect anomalies
anomalies_df = detect_anomalies(ais_data)
print("Anomalies detected:")
print(anomalies_df)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Anomalies detected:
#               MMSI        BaseDateTime       LAT       LON  SOG    COG  \
# 11516            0 2024-01-29 00:01:17  43.64546 -70.24829  0.0  125.2
# 15989            0 2024-01-29 00:02:27  43.64546 -70.24828  0.0  342.4
# 19896            0 2024-01-29 00:03:36  43.64546 -70.24828  0.0   80.9
# 161767           0 2024-01-29 00:04:45  43.64546 -70.24828  0.0  257.8
# 39375            0 2024-01-29 00:08:05  43.64547 -70.24828  0.0    0.0
# ...            ...                 ...       ...       ...  ...    ...
# 4364752  998975541 2024-01-29 17:22:08  30.28763 -87.55561  0.0   62.5
# 4436542  998975541 2024-01-29 17:37:38  30.28633 -87.55659  0.8  222.9
# 4438504  998975541 2024-01-29 17:39:07  30.28638 -87.55654  0.2  133.8
# 4443615  998975541 2024-01-29 17:40:38  30.28655 -87.55630  0.0   61.8
# 6432492  998975541 2024-01-29 22:43:38  30.28476 -87.55924  0.0   82.6
#
#          Heading VesselName         IMO CallSign  VesselType  Status  Length  \
# 11516      235.0    CG49420         NaN     NWHE        51.0    15.0    82.0
# 15989      234.0    CG49420         NaN     NWHE        51.0    15.0    82.0
# 19896      235.0    CG49420         NaN     NWHE        51.0    15.0    82.0
# 161767     235.0    CG49420         NaN     NWHE        51.0    15.0    82.0
# 39375      234.0    CG49420         NaN     NWHE        51.0    15.0    82.0
# ...          ...        ...         ...      ...         ...     ...     ...
# 4364752    511.0    PATRONE  IMO0000000      NaN        37.0     NaN    30.0
# 4436542    511.0    PATRONE  IMO0000000      NaN        37.0     NaN    30.0
# 4438504    511.0    PATRONE  IMO0000000      NaN        37.0     NaN    30.0
# 4443615    511.0    PATRONE  IMO0000000      NaN        37.0     NaN    30.0
# 6432492    511.0    PATRONE  IMO0000000      NaN        37.0     NaN    30.0
#
#          Width  Draft  Cargo TransceiverClass
# 11516     12.0    1.6   51.0                A
# 15989     12.0    1.6   51.0                A
# 19896     12.0    1.6   51.0                A
# 161767    12.0    1.6   51.0                A
# 39375     12.0    1.6   51.0                A
# ...        ...    ...    ...              ...
# 4364752    9.0    NaN    NaN                B
# 4436542    9.0    NaN    NaN                B
# 4438504    9.0    NaN    NaN                B
# 4443615    9.0    NaN    NaN                B
# 6432492    9.0    NaN    NaN                B
#
# [1144908 rows x 17 columns]

# %%
# Install necessary packages
# !pip install geemap
# !pip install earthengine-api
# Install Earth Engine and Geemap
# !pip install earthengine-api geemap


# Authenticate and initialize Earth Engine
import ee
import geemap

# Trigger the authentication
ee.Authenticate()

# Initialize the Earth Engine API
ee.Initialize(project='ee-oilspilldetection-by-uday')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Requirement already satisfied: geemap in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (0.35.3)
# Requirement already satisfied: bqplot in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.12.44)
# Requirement already satisfied: colour in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: earthengine-api>=1.0.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (1.5.6)
# Requirement already satisfied: eerepr>=0.1.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.1.1)
# Requirement already satisfied: folium>=0.17.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.19.5)
# Requirement already satisfied: geocoder in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.19.2)
# Requirement already satisfied: ipytree in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (3.10.1)
# Requirement already satisfied: numpy in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (2.2.3)
# Requirement already satisfied: plotly in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (6.0.0)
# Requirement already satisfied: pyperclip in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (7.3.2)
# Requirement already satisfied: scooby in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.10.0)
# Requirement already satisfied: google-cloud-storage in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api>=1.0.0->geemap) (3.1.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.163.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.38.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api>=1.0.0->geemap) (0.22.0)
# Requirement already satisfied: requests in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api>=1.0.0->geemap) (2.32.3)
# Requirement already satisfied: branca>=0.6.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from folium>=0.17.0->geemap) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from folium>=0.17.0->geemap) (3.1.6)
# Requirement already satisfied: xyzservices in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from folium>=0.17.0->geemap) (2025.1.0)
# Requirement already satisfied: ipywidgets in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.5)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from bqplot->geemap) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from pandas->geemap) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from pandas->geemap) (2025.1)
# Requirement already satisfied: click in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geocoder->geemap) (8.1.8)
# Requirement already satisfied: future in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geocoder->geemap) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (3.2.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from plotly->geemap) (1.30.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (4.9)
# Requirement already satisfied: comm>=0.1.3 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.34.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: colorama in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-cloud-storage->earthengine-api>=1.0.0->geemap) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api>=1.0.0->geemap) (2025.1.31)
# Requirement already satisfied: decorator in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ratelim->geocoder->geemap) (5.2.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.69.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (4.25.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.0.0->geemap) (1.26.1)
# Requirement already satisfied: exceptiongroup in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.12.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=1.0.0->geemap) (0.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)
# Requirement already satisfied: earthengine-api in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (1.5.6)
# Requirement already satisfied: google-cloud-storage in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (3.1.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (2.163.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (2.38.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (0.22.0)
# Requirement already satisfied: requests in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (2.32.3)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.2.1)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-cloud-storage->earthengine-api) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-cloud-storage->earthengine-api) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-cloud-storage->earthengine-api) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api) (2025.1.31)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.69.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (4.25.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.26.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.6.1)
# Requirement already satisfied: earthengine-api in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (1.5.6)
# Requirement already satisfied: geemap in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (0.35.3)
# Requirement already satisfied: google-cloud-storage in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (3.1.0)
# Requirement already satisfied: google-api-python-client>=1.12.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (2.163.0)
# Requirement already satisfied: google-auth>=1.4.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (2.38.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (0.2.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (0.22.0)
# Requirement already satisfied: requests in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from earthengine-api) (2.32.3)
# Requirement already satisfied: bqplot in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.12.44)
# Requirement already satisfied: colour in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.1.5)
# Requirement already satisfied: eerepr>=0.1.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.1.1)
# Requirement already satisfied: folium>=0.17.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.19.5)
# Requirement already satisfied: geocoder in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (1.38.1)
# Requirement already satisfied: ipyevents in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (2.0.2)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.19.2)
# Requirement already satisfied: ipytree in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.2.2)
# Requirement already satisfied: matplotlib in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (3.10.1)
# Requirement already satisfied: numpy in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (1.26.4)
# Requirement already satisfied: pandas in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (2.2.3)
# Requirement already satisfied: plotly in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (6.0.0)
# Requirement already satisfied: pyperclip in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (1.9.0)
# Requirement already satisfied: pyshp>=2.3.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (2.3.1)
# Requirement already satisfied: python-box in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (7.3.2)
# Requirement already satisfied: scooby in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geemap) (0.10.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from folium>=0.17.0->geemap) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from folium>=0.17.0->geemap) (3.1.6)
# Requirement already satisfied: xyzservices in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from folium>=0.17.0->geemap) (2025.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (2.24.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-python-client>=1.12.1->earthengine-api) (4.1.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-auth>=1.4.1->earthengine-api) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from httplib2<1dev,>=0.9.2->earthengine-api) (3.2.1)
# Requirement already satisfied: ipywidgets in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipyfilechooser>=0.6.0->geemap) (8.1.5)
# Requirement already satisfied: jupyter-leaflet<0.20,>=0.19 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.19.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipyleaflet>=0.19.2->geemap) (0.2.1)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from bqplot->geemap) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from pandas->geemap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from pandas->geemap) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from pandas->geemap) (2025.1)
# Requirement already satisfied: click in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geocoder->geemap) (8.1.8)
# Requirement already satisfied: future in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geocoder->geemap) (1.0.0)
# Requirement already satisfied: ratelim in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: six in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from geocoder->geemap) (1.17.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-cloud-storage->earthengine-api) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-cloud-storage->earthengine-api) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-cloud-storage->earthengine-api) (1.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from requests->earthengine-api) (2025.1.31)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from matplotlib->geemap) (11.1.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from plotly->geemap) (1.30.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.69.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (4.25.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api) (1.26.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (8.34.0)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.13)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from jinja2>=2.9->folium>=0.17.0->geemap) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api) (0.6.1)
# Requirement already satisfied: colorama in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from click->geocoder->geemap) (0.4.6)
# Requirement already satisfied: decorator in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ratelim->geocoder->geemap) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (4.12.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\uday kiran ambati\onedrive\desktop\major_project\code\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->ipyfilechooser>=0.6.0->geemap) (0.2.3)

# %%
def plot_histogram(image, region, title):
    try:
        array = image.reduceRegion(
            reducer=ee.Reducer.toList(),
            geometry=region,
            scale=30,
            maxPixels=1e9
        ).get('VV')

        # Check if array is empty
        if array is None:
            print("No VV data available for histogram plot.")
            return

        array = np.array(array.getInfo())
        plt.hist(array, bins=50, color='blue', alpha=0.7)
        plt.title(title)
        plt.xlabel('VV (dB)')
        plt.ylabel('Frequency')
        plt.grid()
        plt.show()
    except Exception as e:
        print(f"Error plotting histogram: {e}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from datetime import datetime

# Function to parse date from BaseDateTime
def extract_date(base_date_time):
    # Convert to string if it’s a Timestamp
    if isinstance(base_date_time, pd.Timestamp):
        base_date_time = base_date_time.strftime('%Y-%m-%dT%H:%M:%S')
    else:
        base_date_time = str(base_date_time)

    # Parse the date
    date_time_obj = datetime.strptime(base_date_time, '%Y-%m-%dT%H:%M:%S')
    return date_time_obj.strftime('%Y-%m-%d')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def preprocess_image_for_model(image_np):
    """ Preprocess the NumPy array image to match model input requirements """
    # Resize the image to (256, 256)
    resized_image = cv2.resize(image_np, (256, 256))
    
    # Check the number of channels
    if resized_image.shape[-1] == 2:
        # Convert 2-channel input to 3-channel by duplicating one of the channels
        resized_image = np.repeat(resized_image[:, :, :1], 3, axis=-1)
    elif resized_image.shape[-1] == 1:
        # Convert 1-channel input to 3-channel
        resized_image = np.repeat(resized_image, 3, axis=-1)
    elif resized_image.shape[-1] != 3:
        raise ValueError(f"Unexpected number of channels: {resized_image.shape[-1]}")
    
    # Add a batch dimension
    return np.expand_dims(resized_image, axis=0)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import tensorflow as tf

# Define jaccard_coef if not already defined
def jaccard_coef(y_true, y_pred):
    y_true_flatten = tf.reshape(y_true, [-1])
    y_pred_flatten = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_flatten * y_pred_flatten)
    sum_ = tf.reduce_sum(y_true_flatten) + tf.reduce_sum(y_pred_flatten)
    smooth = 1e-6  # To avoid division by zero
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
import tensorflow as tf
import segmentation_models as sm
from tensorflow.keras.models import load_model

# Define loss functions
dice_loss = sm.losses.DiceLoss()
focal_loss = sm.losses.CategoricalFocalLoss()

# Custom objects dictionary
custom_objects = {
    "jaccard_coef": jaccard_coef,
    "DiceLoss": dice_loss,
    "CategoricalFocalLoss": focal_loss,
}

# Load models
hybrid_model = load_model(r"C:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\saved_models\hybrid_model.h5")
unet_model = load_model(r"C:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\saved_models\U_net.h5")
deeplab_model = load_model(
    r"C:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\saved_models\deeplab_model.h5",
    custom_objects=custom_objects
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 17
#      10 custom_objects = {
#      11     "jaccard_coef": jaccard_coef,
#      12     "DiceLoss": dice_loss,
#      13     "CategoricalFocalLoss": focal_loss,
#      14 }
#      16 # Load models
# ---> 17 hybrid_model = load_model(r"C:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\saved_models\hybrid_model.h5",custom_objects=custom_objects)
#      18 unet_model = load_model(r"C:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\saved_models\U_net.h5",custom_objects=custom_objects)
#      19 deeplab_model = load_model(
#      20     r"C:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\saved_models\deeplab_model.h5",
#      21     custom_objects=custom_objects
#      22 )
#
# File c:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\.venv\lib\site-packages\keras\src\saving\saving_api.py:262, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     254     return saving_lib.load_model(
#     255         filepath,
#     256         custom_objects=custom_objects,
#     257         compile=compile,
#     258         safe_mode=safe_mode,
#     259     )
#     261 # Legacy case.
# --> 262 return legacy_sm_saving_lib.load_model(
#     263     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     264 )
#
# File c:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\.venv\lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\Uday Kiran Ambati\OneDrive\Desktop\major_project\Code\.venv\lib\site-packages\keras\src\engine\base_layer.py:870, in Layer.from_config(cls, config)
#     868     return cls(**config)
#     869 except Exception as e:
# --> 870     raise TypeError(
#     871         f"Error when deserializing class '{cls.__name__}' using "
#     872         f"config={config}.\n\nException encountered: {e}"
#     873     )
#
# TypeError: Error when deserializing class 'InputLayer' using config={'batch_shape': [None, 256, 256, 3], 'dtype': 'float32', 'sparse': False, 'name': 'input_layer_1'}.
#
# Exception encountered: Unrecognized keyword arguments: ['batch_shape']

# %%
def confirm_oil_spill(hybrid_model, unet_model, deeplab_model, image):
    """ 
    Confirm oil spill detection using Hybrid, UNet, and DeepLabV3+ models. 
    Requires agreement among all models.
    """
    processed_image = preprocess_image_for_model(image)

    # Get predictions from all three models
    hybrid_prediction = hybrid_model.predict(processed_image)
    unet_prediction = unet_model.predict(processed_image)
    deeplab_prediction = deeplab_model.predict(processed_image)

    # Assuming '1' corresponds to oil spill detection
    hybrid_result = np.argmax(hybrid_prediction) == 1
    unet_result = np.argmax(unet_prediction) == 1
    deeplab_result = np.argmax(deeplab_prediction, axis=-1).squeeze() == 1

    # Confirm only if all models agree
    return hybrid_result and unet_result and deeplab_result
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
from tensorflow.keras.models import load_model
import geemap
import ee
import numpy as np
import cv2
from IPython.display import display
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import get_custom_objects
def process_anomaly(row):
    lat = row['LAT']
    lon = row['LON']
    base_date_time = row['BaseDateTime']
    date = extract_date(base_date_time)
    anomaly_date = ee.Date(date)
    print(f"Processing anomaly at {lat}, {lon} on {date}")

    roi = ee.Geometry.Point(lon, lat).buffer(10000).bounds()
    detected_spills = []

    sen1 = ee.ImageCollection("COPERNICUS/S1_GRD") \
        .filterDate(anomaly_date, anomaly_date.advance(1, 'day')) \
        .filterBounds(roi) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VV')) \
        .filter(ee.Filter.listContains('transmitterReceiverPolarisation', 'VH')) \
        .filter(ee.Filter.eq('instrumentMode', 'IW'))

    if sen1.size().getInfo() == 0:
        print("No Sentinel-1 VV or VH images available. Trying Sentinel-2.")
        sen1 = ee.ImageCollection("COPERNICUS/S2_SR_HARMONIZED") \
            .filterDate(anomaly_date, anomaly_date.advance(1, 'day')) \
            .filterBounds(roi) \
            .filter(ee.Filter.eq('CLOUDY_PIXEL_PERCENTAGE', 0))

        if sen1.size().getInfo() == 0:
            print("No Sentinel-2 images available for this date and location.")
            return

        sen1_image = sen1.select(['B4', 'B8']).mosaic()
    else:
        sen1_image = sen1.select(['VV', 'VH']).mosaic()

    despeckled = sen1_image.focal_mean(100, 'square', 'meters')
    vv_dark = despeckled.select('VV').lt(-22)
    vh_dark = despeckled.select('VH').lt(-18)
    oil_spill_detection = vv_dark.And(vh_dark)

    mask = oil_spill_detection.updateMask(oil_spill_detection)
    area = mask.multiply(ee.Image.pixelArea().divide(1e6))
    oil_spill_area = ee.Number(
        area.reduceRegion(
            reducer=ee.Reducer.sum(),
            geometry=roi,
            scale=100
        ).values().get(0)
    ).getInfo()

    if oil_spill_area > 0:
        print(f"Detected Oil Spill Area (sq. km): {oil_spill_area}")

        despeckled_np = geemap.ee_to_numpy(despeckled, bands=['VV', 'VH'], region=roi, scale=100)
        processed_image = preprocess_image_for_model(despeckled_np)

# Confirm using all three models
#if confirm_oil_spill(hybrid_model, unet_model, deeplab_model, processed_image):
 #   detected_spills.append(oil_spill_area)

        #hybrid_model = load_model(r"C:\Users\harsh\OneDrive\Desktop\Capstone\hybrid_model.h5")
        #unet_model = load_model(r"C:\Users\harsh\OneDrive\Desktop\Capstone\U_net.h5")
        # If using custom layers/functions
        # deeplab_model = load_model(
        #     r"C:\Users\harsh\OneDrive\Desktop\Capstone\deeplab_model.h5",
        #     custom_objects=get_custom_objects()
        # )

        # Confirm using all three models
        if confirm_oil_spill(hybrid_model, unet_model, deeplab_model, despeckled_np):
            detected_spills.append(oil_spill_area)

            oil_spill_vis_params = {
                'min': 0,
                'max': 1,
                'palette': ['blue', 'cyan', 'yellow', 'red']
            }

            Map = geemap.Map()
            Map.centerObject(roi)
            Map.addLayer(sen1_image, {'bands': ['VV', 'VH'], 'min': -30, 'max': 0}, f'Sentinel-1 Image {anomaly_date.getInfo()}')
            Map.addLayer(despeckled.clip(roi), {}, 'Despeckled Image', False)
            Map.addLayer(oil_spill_detection.clip(roi), {}, 'Oil Spill Detection', False)
            oil_spill_vector = mask.reduceToVectors(
                geometry=roi,
                scale=100
            )
            Map.addLayer(oil_spill_vector, {}, 'Oil Spill Vector', False)

    if detected_spills:
        print(f"Oil spills detected over the days: {detected_spills}")
        Map.addLayerControl()
        return Map
    else:
        print("No significant oil spills detected across the checked dates.")
        return None
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Iterate over each anomaly in the DataFrame and process
for index, row in anomalies_df.iterrows():
    result_map = process_anomaly(row)
    if result_map:
        display(result_map)  # This displays the map in interactive environments
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Processing anomaly at 25.78166, -80.15023 on 2024-01-01
# Detected Oil Spill Area (sq. km): 178.70174741171064
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 904ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 832ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 27.78969, -97.39082 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 32.02417, -81.04617 on 2024-01-01
# Detected Oil Spill Area (sq. km): 17.5633537601677
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 47.98236, -122.21983 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 28.17053, -89.22213 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 40.66659, -125.20548 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 26.09262, -80.11391 on 2024-01-01
# Detected Oil Spill Area (sq. km): 23.726947161366574
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 30.52469, -88.09334 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 49.29048, -123.06089 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 49.30471, -123.05769 on 2024-01-01
# No Sentinel-1 VV or VH images available. Trying Sentinel-2.
# No Sentinel-2 images available for this date and location.
# Processing anomaly at 48.68902, -123.40947 on 2024-01-01
# Detected Oil Spill Area (sq. km): 204.79842854767278
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# No significant oil spills detected across the checked dates.
# Processing anomaly at 49.3764, -123.27094 on 2024-01-01
